# %%
from mcp import StdioServerParameters
from utils import HttpAgent, StdioAgent, MultiAgent, create_backend
import os

# %%
from experiments.tests import TESTS
TESTS

# %%
# ── Config ───────────────────────────────────────────────────────────────────
MODEL        = "qwen3:14b"               # any model pulled in Ollama
OLLAMA_HOST  = "https://demo.narancsle.cc" # Proxied to WARA-OPS, authentication required
AUTH = {
    "CF-Access-Client-Id":     os.environ.get("CF_Access_Client_Id"),
    "CF-Access-Client-Secret": os.environ.get("CF_Access_Client_Secret"),
}
#OLLAMA_HOST  = "http://127.0.0.1:11434"  # default Ollama address
ALLOWED_DIR  = "/home/jovyan"            # directory the MCP server can access
MCP_CRML_URL = "https://crml-mcp.narancsle.cc/mcp"
# ─────────────────────────────────────────────────────────────────────────────

backend = await create_backend("ollama", MODEL, host=OLLAMA_HOST, headers=AUTH)

# %%
# Multi-turn conversation via HTTP MCP server
async with MultiAgent([MCP_CRML_URL], backend) as agent:
    await agent.chat("What tools do you have available?")
    await agent.chat("Write a simple CRML model for a DC/DC converter.")
    await agent.chat("Check the syntax of the model you just wrote. Fix the model if there are errors and repeat the task until the model is correct.")
